# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiochaza/pandas/blob/main/Lectura_de_datos_con_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Manipular txt, csv, xlsx, json

# %%
import pandas as pd

# %%
#Lee los archivos dates y dates_4 (txt)
ruta_txt = "/content/clientes.txt"
df_txt = pd.read_csv(ruta_txt, sep="\t") #Ponemos la t, porque está con tabulacion
df_txt.head()
# Out:
#    cliente_id            nombre             telefono  \
# 0           1     Troy Morrison    299-354-0572x6492
# 1           2   Jermaine Forbes  (035)822-1327x24700
# 2           3    Linda Mcdonald         095-385-8727
# 3           4  Jessica Hamilton         100.182.2932
# 4           5      Sierra Huynh           1149947726
#
#                         correo fecha_registro
# 0  gouldmarcus@short-brown.com     2024-04-15
# 1      sanchezcarrie@yahoo.com     2024-09-28
# 2        moraspencer@gmail.com     2025-04-24
# 3    tami24@estrada-flores.com     2023-11-19
# 4   caitlynhernandez@yahoo.com     2023-09-04

# %%
#Leer los archivos csv
ruta_csv = "/content/clientes.csv"
df_csv = pd.read_csv(ruta_csv)
df_csv.head()
# Out:
#    cliente_id            nombre             telefono  \
# 0           1     Troy Morrison    299-354-0572x6492
# 1           2   Jermaine Forbes  (035)822-1327x24700
# 2           3    Linda Mcdonald         095-385-8727
# 3           4  Jessica Hamilton         100.182.2932
# 4           5      Sierra Huynh           1149947726
#
#                         correo fecha_registro
# 0  gouldmarcus@short-brown.com     2024-04-15
# 1      sanchezcarrie@yahoo.com     2024-09-28
# 2        moraspencer@gmail.com     2025-04-24
# 3    tami24@estrada-flores.com     2023-11-19
# 4   caitlynhernandez@yahoo.com     2023-09-04

# %%
#Leer archivos xlsl
ruta_xlsx = "/content/base_datos.xlsx"
df_xlsx = pd.read_excel(ruta_xlsx)
df_xlsx.head()
# Out:
#    cliente_id            nombre             telefono  \
# 0           1     Troy Morrison    299-354-0572x6492
# 1           2   Jermaine Forbes  (035)822-1327x24700
# 2           3    Linda Mcdonald         095-385-8727
# 3           4  Jessica Hamilton         100.182.2932
# 4           5      Sierra Huynh           1149947726
#
#                         correo fecha_registro
# 0  gouldmarcus@short-brown.com     2024-04-15
# 1      sanchezcarrie@yahoo.com     2024-09-28
# 2        moraspencer@gmail.com     2025-04-24
# 3    tami24@estrada-flores.com     2023-11-19
# 4   caitlynhernandez@yahoo.com     2023-09-04

# %%
#Leer archivos excel
ruta_json = "/content/clientes.json"
df_json = pd.read_json(ruta_json, lines=True)
df_json.head()
# Out:
#    cliente_id            nombre             telefono  \
# 0           1     Troy Morrison    299-354-0572x6492
# 1           2   Jermaine Forbes  (035)822-1327x24700
# 2           3    Linda Mcdonald         095-385-8727
# 3           4  Jessica Hamilton         100.182.2932
# 4           5      Sierra Huynh           1149947726
#
#                         correo  fecha_registro
# 0  gouldmarcus@short-brown.com   1713139200000
# 1      sanchezcarrie@yahoo.com   1727481600000
# 2        moraspencer@gmail.com   1745452800000
# 3    tami24@estrada-flores.com   1700352000000
# 4   caitlynhernandez@yahoo.com   1693785600000
