# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiochaza/pandas/blob/main/pandas_desde_cero_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #La Clase de Obetos DataFrame
#
# Un objeto del tipo DataFrame define un conjunto de datos estructurados en forma de tabla donde cada columna es un objeti de tipo Series, es decir, todos los datos de una misma columna son del mismo tipo, y las filas son registros que pueden contener datos de distintos tipos.
#
# Un DataFrame contiene dos índices, uno para las filas y otro para las columnas, y se puede acceder a sus elementos mediante los nombres de las filas y columnas
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Creación de un DataFrame a partir de un diccionario de listas
#
# Para crear un DataFram a partir de un diccionario cuya claves son los nombres de las columnas y los valores son listas con los datos de las columnas se utiliza el método:
#
#           DataFrame(data=diccionario, index=filas, columns=columnas, dtype=tipo
#             Devuelve un oobjeto del tipo DataFrame cuya columnas son las listas contenidads en los valores del diccionario, los nombres de filas indicados en la lista filas, los nombres de columnas indicados en la lista columnas y los tipos indicados en la lista tipos. La lista filas tiene que tener el mismo tamaño que el diccionario. Si no se pasa la lista de filas se utilizan como nombres los enteros empezando en 0. Si nose pasa la lista de columnas se utilizan como nombres las claves del diccionario- Si no se pasa la lista de tipos, se infiere.
#
# Los valores asociados a las clvaes del diccionario deben ser listas del mismo tamaño

# %%
import pandas as pd
datos = {"nombre":["Maria" , "Luis", "Carmen", "Antonio"],
         "edad":[18,20,19,22],
         "grado":["Economia", "Medicina", "Arquitectura", "Economia"],
         "correo":["maria@gmail.com", "luis@gmail.com", "carmen@gmail.com", "antonio@gmail.com"]}

df = pd.DataFrame(datos)

# %%
df
# Out:
#     nombre  edad         grado             correo
# 0    Maria    18      Economia    maria@gmail.com
# 1     Luis    20      Medicina     luis@gmail.com
# 2   Carmen    19  Arquitectura   carmen@gmail.com
# 3  Antonio    22      Economia  antonio@gmail.com

# %% [markdown]
# #Creación de un DataFrame a partir de una lista de listas
# para crear un data frmae a partir de una lista de listas con los datos de las columnas se utiliza el siguiente método
#
#       DataFrame(data=listas, idex=filas, columns=columnas, dtyipe=tipos)
#       Devuelve un objeto del tipo DataFrame cuyas columnas son los valores de la lista listas, los nombres de las filas ubducadis eb ka kusta fialas, los nombres de las columnas indicados en la lista columnas y los tipos indicados en la lista tipos. La lista filas, tiene que tener el mismo tamaño que la lista listas mientra que las listas columnas y tipos tienen que tener el mismo tamño que las listas anidadas en listas, Sino se pasa la lista filas o columnas se utilizan enteros empezando en 0. Si no se pasa la lista de tipos, se infiere.
#
# Si las listas anidadas en listas no tienen el mismo tamaño, las listas menores se rellenan con los valore NaN

# %%
import pandas as pd
df = pd.DataFrame([["Maria", 18], ["Luis", 22], ["Carmen", 20]], columns= ["Nombre", "Edad"])
print(df)
# Out:
#    Nombre  Edad
# 0   Maria    18
# 1    Luis    22
# 2  Carmen    20

# %% [markdown]
# #Creación de un DataFrame a partir de una lista de diccionarios
#
# Para crear un DataFrame a partir de una lista de diccionarios con los datos de las dilas, se utiliza el siguiente método
#
#       DataFrame (data=diccionarios, index=filas, columns=columnas, dytipe = tipos):
#         Devuelve el objeto del tipo DataFrame cuyas filas contienen los valores ed los diccionarios de la lista diccionarios, los nombres de las filas indicados en la lista filas, los nombres de las columnas indicados en la lista columnas y los tipos indicados en la lista tipos. La lista filas tiene que tener el mismo tamaño que la lista listas. Si no se pasa la lista de filas se utilizan enteros empezando en el 0. Si no se pasa la lista de columnas se utilizan las claves de los diccionarios. SI no se pasa la listas de tipo, se infiere
# Si los diccionarios no tienen las mismas claves, las claves que no aparecen en el diccionario se rellenan con NaN

# %%
import pandas as pd
df = pd.DataFrame([{"Nombre": "Maria", "Edad": 18}, {"Nombre": "Luis", "Edad": 22}, {"Nombre": "Carmnen"}])
df
# Out:
#     Nombre  Edad
# 0    Maria  18.0
# 1     Luis  22.0
# 2  Carmnen   NaN

# %% [markdown]
# #Cración de un DataFrame a partir de un array
# Para crear un DataFrame a partir de un array de NumPy se utiliza el siguiente método
#      DataFrame(datos=array, index=filas, columns=columnas, dtype=tipo)
#      Devuelve un objeto del tipo DataFrame cuyas filas y columnas son las del array, los nombres de filas indicados en la lista filas, los nombres de las columnas indicados en la lista columnas y el tipo indicado en tipo. La lista filas tiene que tener el mismo tamaño que el número de columnas del array. Sino se pasa la lista de filas se utilizan enteros empezando desde el 0. Si no se pasa la lista de columnas se utilizan las claves de los diccionarios. Si no se pasa la lista de tipos, se infiere

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(4,3), columns=["a", "b", "c"])
df
# Out:
#           a         b         c
# 0 -0.014753  0.258584 -1.429115
# 1  0.135848 -0.576541 -0.088162
# 2  0.138469 -0.790823 -0.603119
# 3 -0.570938 -0.121959 -0.439727

# %% [markdown]
# #Creación de un DataFrame a partir de un fichero CSV o XLXS (Excel)
#
# Dependiendo del tipo de fichero, existen distintas funciones para importar un DataFrame desde un fichero
#
#       Read_csv()
#         Valores separados por comas o cualquier otro separador y convertirlos en un DataFrame. Es una función de pandas que sirve para leer archivos .Csv(Valores separados por comas o cualquier otro separador)
#
#
#       read_csv(fichero.csv, sep=separador, header=n, index_col=m, na_values=no-validos, decimal=separador-decimal)
#
#       **Desglose del codigo**
#         * fichero.csv = es el nombre el archivo que quieres leer, puede ser una ruta
#         * sep = Es un separador de columnas
#                 * Por defecto es la coma, porque así son los clasivos
#                 * Se puede usar otros, si es que el archivo lo usa: ;,|, tabulacion
#
#         *header = n : indica en qué filas están los nombres de las columanas
#                 * header=0 (por defecto): los nombres están en la rpimera fila
#                 * header=None: si el archivo no tiene cabecera y querés que pandas genere nombres como 0,1,2,etc
#         *index_col=m = especifica que columna vas a usar como índice
#                 * index_col=0 : hace que pandas use la primera columna como indice
#         *na_values=no-validos = especifica que valores se van a considerar faltantes o NaN
#         *decimal = separador-decimal = le dice a pandas qué símbolo se está usando para los decimales
#
#
#       Deuevlve un objeto del tipo DataFrame con los datos del fichero CSV dichero.csv usando como separador de los datos de la cadena separador. Como nombres de columnas se utiliza los valores de la fila n y como nombres de filas los valores de la columna m. Si no se indica m se uiizan como nombres de filas los enteros empezando en 0. Los valores incluídos en la lista no-validos se converten en NaN. Para los datos numéricos se utiliza como separador de decimales el cáracter indicado en separador-decimal
#
#
# Carga a partir de un excel
#
#       read_excel(fichero.xlsx, sheet_name=hoja, header=n, index_col=m, na_values=no-validos, decimal=separador-decimal):
#
#
#       read_excel() = es una función de Pandas que te permite leer archivos de excel y convertirlos en un data frame
#
#       fichero.xlsx = es el nombre del archivo excel o la ruta al archivo
#
#       sheet_name = indica qué hoja del archivo quieres leer.
#                 * Puede ser el nombre de la hoja "exportación"
#                 * o el número de la hoja(empezando en 0): 0
#               Si el archivo tiene varias hojas y no pones nada, lee la primera hoja por defecto
#
#       header = indica en que fila están los nombres de la columna
#               * header = 0 los nombres están en la primera fila (fila 0)
#               * header=None = no hay nombres y pandas asigna automaticamente
#
#       idex_col = que columna utilizas como indice
#               * index_col=0 usa la primera columna como índice
#               * None usa número automáticos como índice (0,1,2..)
#       usecols = sirve para leer solo algunas columnas, no todas
#               * Podrias indicar
#                     * Nombres: ["Nombre", "Edad"]
#                     * Letras de Excel: "A:C"
#                     * Números de columna: [0,2]
#       na_values = Lista de valores que deben ser tratados como faltantes (NaN)
#
#       dytipe =  Fuerza a que las columnas sean de cierto tipo
#
#
# Devuelve un objeto del tipo DataFrame con los datos de la hoja de cálculo hoja del fichero Excel Fichero.xlsx. Como nombres de columnas se utiliza los valores de la fila n y como nombres de fila los valores de la columna m. Si no se indica m se utilizan como nombres de filas los enteros empezando en 0. Los valores incluídos en la lista no-validos se convierten en NaN. Para los datos númerico se utiliza como separador deciles el carácter indicado en separador_decimal.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = "/content/drive/MyDrive/Bases de datos /esperanza_de_vida.csv"
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", decimal=",", encoding="latin1")

# %%
print(df.head())
# Out:
#               anio mujeres varones
# provincia
# Buenos Aires  2015   80.22   73.54
# Buenos Aires  2020   81.34   74.74
# Buenos Aires  2025   82.32    75.8
# Buenos Aires  2030    83.2   76.76
# Buenos Aires  2035   83.98    77.6

# %% [markdown]
# #Exportación de ficheros
# Tambien existen funciones para exportar un DataFrame a un fichero con diferentes formatos
#
#       df.to_csv(fichero.csv, sep=separador, columns=booleanos, index=booleano):
#       Exporta el DataFrame df al fichero fichero.csv en formato CSV usando como separador de los datos la cadena separador. Si se pasa TRue al parámetro columns se exporta también la fila con los nombres de las columnas y si se pas aTrue al parametro index se exporta tambien la columna con los nombres de la fila
#
#       df.to_excel(fichero.xlsl, sheet_name = hoja, columns=booleano, index=booleano): Expora el DataFrame df a la hoja de cálculo hoja del fichero.xlsx en formato excel. Si se pasa True al parámetro columns se exporta tambien la fila con los nombres de columnas y si se pasa true al parametro index se exporta también la columna con los nombres de la fila

# %% [markdown]
# #Atributos de un DataFrame
# Exiten varias propiedades o métodos para ver las características de un DataFrame
#
#       * df.info()
#         Devuelve la indormación(número de filas, número de columnas, índices, tipo de las columnas y memoria usado) Sobre el DataFrame df
#
#       * df.shape()
#         Devuelve una tupla con el número de filas y columnas del DataFrame df
#
#       *df.size()
#         Devuelve el número ed elementos del DataFrame
#
#       *df.columns()
#         Devuelve una lista con los nombres de las columnas del DataFrame df
#
#       * df.index()
#         Devuelve una lista con los nombres de las filas del DataFrame df ej(id)
#
#       * df.dtypes()
#         Devuelve una serie con los tipos de datos de las columnas del DataFrame df
#
#       * df.head(n): devuelve las n primeras filas del DataFrame df
#
#       *df.tail(n): Devuelve las n últimas filas del DataFrame df

# %%
import pandas as pd
df
# Out:
#               anio mujeres varones
# provincia
# Buenos Aires  2015   80.22   73.54
# Buenos Aires  2020   81.34   74.74
# Buenos Aires  2025   82.32    75.8
# Buenos Aires  2030    83.2   76.76
# Buenos Aires  2035   83.98    77.6
# ...            ...     ...     ...
# Tucumán       2020   81.05   75.11
# Tucumán       2025   82.11   76.15
# Tucumán       2030   83.03   77.07
# Tucumán       2035   83.84   77.88
# Tucumán       2040   84.54   78.58
#
# [144 rows x 3 columns]

# %%
import pandas as pd
ruta ="/content/drive/MyDrive/Bases de datos /esperanza_de_vida.csv"
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", decimal=",", encoding="latin1")

print("Info de la base de datos")
print(df.info)
print("Numero de filas y columnas")
print(df.shape)
print("Numero de elementos")
print(df.size)
print("Nombres de las columnas")
print(df.columns)
print("Nombres de las filas")
print(df.index)
print("Tipo de datos de las columnas")
print(df.dtypes)
print("Primeras 10 filas del DataFrame")
print(df.head(10))
print("Ultimas 10 filas del DataFrame")
print(df.tail(10))
# Out:
# Info de la base de datos
# <bound method DataFrame.info of               anio mujeres varones
# provincia
# Buenos Aires  2015   80.22   73.54
# Buenos Aires  2020   81.34   74.74
# Buenos Aires  2025   82.32    75.8
# Buenos Aires  2030    83.2   76.76
# Buenos Aires  2035   83.98    77.6
# ...            ...     ...     ...
# Tucumán       2020   81.05   75.11
# Tucumán       2025   82.11   76.15
# Tucumán       2030   83.03   77.07
# Tucumán       2035   83.84   77.88
# Tucumán       2040   84.54   78.58
#
# [144 rows x 3 columns]>
# Numero de filas y columnas
# (144, 3)
# Numero de elementos
# 432
# Nombres de las columnas
# Index(['anio', 'mujeres', 'varones'], dtype='object')
# Nombres de las filas
# Index(['Buenos Aires', 'Buenos Aires', 'Buenos Aires', 'Buenos Aires',
#        'Buenos Aires', 'Buenos Aires', 'Catamarca', 'Catamarca', 'Catamarca',
#        'Catamarca',
#        ...
#        'Tierra del Fuego', 'Tierra del Fuego', 'Tierra del Fuego',
# ...

# %% [markdown]
# #Renombar los nombres de las filas y columnas
#
# Para cambiar el nombre de las filas y las columnas de un DataFrame se utiliza el siguiente método
#
#       df.rename(columns=columnas, index=filas):
#        Devuelve el DataFrame que resulta de renombrar las columnas indicadas en las claves del diccionario columnas consus valores y las filas indicadas en las claves del diccionario filas con sus valores en el DataFrame df

# %%
df = df.rename(columns={"female":"mujeres", "male": "varones"})
df
# Out:
#               anio mujeres varones
# provincia
# Buenos Aires  2015   80.22   73.54
# Buenos Aires  2020   81.34   74.74
# Buenos Aires  2025   82.32    75.8
# Buenos Aires  2030    83.2   76.76
# Buenos Aires  2035   83.98    77.6
# ...            ...     ...     ...
# Tucumán       2020   81.05   75.11
# Tucumán       2025   82.11   76.15
# Tucumán       2030   83.03   77.07
# Tucumán       2035   83.84   77.88
# Tucumán       2040   84.54   78.58
#
# [144 rows x 3 columns]

# %% [markdown]
# #Cambiar el índice de un DataFrame
#
# Aunque el índice de un DataFrame suele dijarse e la creación del mismo, en ocaciones puede ser necesario cambiar el índice una vez creado el DataFrame. Para ello se utiliza el siguiente metodo
#
#       df.set_index(key = columns, verifi:integrity = bool):
#       Devuelve el DataFrame que resulta de eliminar columnas de la lista columnas  y convertirlas en el nuevo indice. El parámetro verigy_integrity recibe un booleano(false por defecto) y realiza un comprobación para evitar duplicados en la clave cuando recibe true

# %%
#Paso el indice a columna
df =df.reset_index()
print(df.set_index("provincia").head())

#Renombrar
# Out:
#               anio mujeres varones
# provincia
# Buenos Aires  2015   80.22   73.54
# Buenos Aires  2020   81.34   74.74
# Buenos Aires  2025   82.32    75.8
# Buenos Aires  2030    83.2   76.76
# Buenos Aires  2035   83.98    77.6

# %% [markdown]
# #Reindexar un Dataframe
#
# Para reordenar los índices de las filas y las colunas de un DataFrame, así como añadir o eliminar índices, se utiliza el siguiente método
#
#     df.reindex(index=filas, columns=columnas, fill_value=relleno):
#       Devuelve el DataFrame df las filas con nombres en la lista filas y las columnas con nombres en la lista columnas, si alguno de los nombres indicados en filas o columnas no existia en el DataFrame df, se crear filas o columnas rellenas con el valor nuevo

# %%
import pandas as pd
df = pd.read_csv(
'https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
print(df.reindex(index=[4, 3, 1], columns=['nombre', 'tensión', 'colesterol']))
# Out:
#                  nombre  tensión  colesterol
# 4  Marisa López Collado      NaN       148.0
# 3   Carmen López Pinzón      NaN       200.0
# 1        Rosa Díaz Díaz      NaN       232.0

# %% [markdown]
# #Acceso a los elementos de un DataFrame
# El acceso a los datos de un DataFrame se puede haer a través de posiciones o través de los nombre de las filas y columnas
#
# #Acceso mediante posiciones
#       * df.iloc[i,j]
#         Devuelve el elemento que se encuentra en la fila i y columna j del DataFrame df. Pueden indicarse secuencias de índices para obtener partes del DataFrame
#
#       * df.iloc[filas,columna]:
#         Devuelve un DataFrame con los elementos de las filas de la lista filas y de la columna de la lista columnas
#
#       * df.iloc[i]:
#         Devuelve una serie con los elementos de la fila i del DataFrame

# %%
df.head(5)
# Out:
#                          nombre  edad sexo  peso  altura  colesterol
# 0  José Luis Martínez Izquierdo    18    H  85.0    1.79       182.0
# 1                Rosa Díaz Díaz    32    M  65.0    1.73       232.0
# 2         Javier García Sánchez    24    H   NaN    1.81       191.0
# 3           Carmen López Pinzón    35    M  65.0    1.70       200.0
# 4          Marisa López Collado    46    M  51.0    1.58       148.0

# %%
#Print posición
print(df.iloc[1,3])
#Print por [Fila, Columns]
print(df.iloc[1, :4])
#Print por fila
print(df.iloc[1])
# Out:
# 65.0
# nombre    Rosa Díaz Díaz
# edad                  32
# sexo                   M
# peso                65.0
# Name: 1, dtype: object
# nombre        Rosa Díaz Díaz
# edad                      32
# sexo                       M
# peso                    65.0
# altura                  1.73
# colesterol             232.0
# Name: 1, dtype: object

# %% [markdown]
# #Acceso a los elementos mediante nombres
#       * df.loc[Fila,columna]:
#        Devuelve el elemento que se encuentra en la fila con nombre fila y la clumna con nombre columna del df
#       * df[columna]: Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df.
#       * df.columna : Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df. Es similar al método anterior pero solo funciona cuando el nombre de la columna no tiene espacios en blanco

# %%
import pandas as pd
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")

print(df.loc[("Buenos Aires","Santiago del Estero"), ("anio", "varones")])
# Out:
#                      anio  varones
# provincia
# Buenos Aires         2015    73.54
# Buenos Aires         2020    74.74
# Buenos Aires         2025    75.80
# Buenos Aires         2030    76.76
# Buenos Aires         2035    77.60
# Buenos Aires         2040    78.32
# Santiago del Estero  2015    72.76
# Santiago del Estero  2020    74.13
# Santiago del Estero  2025    75.35
# Santiago del Estero  2030    76.42
# Santiago del Estero  2035    77.33
# Santiago del Estero  2040    78.13

# %% [markdown]
# #Operaciones con las columnas de un DataFrame

# %% [markdown]
# #Añadir columnas a un DataFrame
#
# el procedimiento para añadir una nueva columna a un DataFrame es similar al de añadir un nuevo par a un diccionario, pero pasando los valores de la columna en una lista o Serie
#
#
#       * df[nombre] = lista añade al dataframe df una nueva columna con el nombre y los valores de la lista. La lsta debe tener el mismo tamaño que el número de filas de df
#
#       * d[nombre] = serie : Añade al DataFrame df una nueva columna con el nombre nombre y los valores de la serie serie. Si el tamaño de la serie es menor que el número de filas df se rellena con valores NaN mientras que si es mayor se recorta

# %%
import pandas as pd
df = pd.read_csv(
'https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
df['diabetes'] = pd.Series([False, False, True, False, True])
df
# Out:
#                              nombre  edad sexo   peso  altura  colesterol  \
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# ...

# %% [markdown]
# #Operaciones sobre columnas
# Puesto que los datos de una misma columna de un DataFrame son del mismo type, es facil aplicar la misma operación a todos los elementos de la columna

# %%
import pandas as pd
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")

print(df["varones"]*100)
print(df["anio"] == 2020)
# Out:
# provincia
# Buenos Aires    7354.0
# Buenos Aires    7474.0
# Buenos Aires    7580.0
# Buenos Aires    7676.0
# Buenos Aires    7760.0
#                  ...
# Tucumán         7511.0
# Tucumán         7615.0
# Tucumán         7707.0
# Tucumán         7788.0
# Tucumán         7858.0
# Name: varones, Length: 144, dtype: float64
# provincia
# Buenos Aires    False
# Buenos Aires     True
# Buenos Aires    False
# Buenos Aires    False
# Buenos Aires    False
#                 ...
# Tucumán          True
# Tucumán         False
# Tucumán         False
# Tucumán         False
# Tucumán         False
# Name: anio, Length: 144, dtype: bool

# %% [markdown]
# #Aplicar Funciones a columnas
#
# para aplicar funciones a todos los elementos de una columna se utiliza el siguiente método:
#       df["Column].apply(f):
#       Devuelve una serie con los valores que resulta de aplicar la función f a los elementos de la columna con nombre columna del DataFrame

# %%
import pandas as pd
from math import log
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")

print(df["varones"].apply(log))
# Out:
# provincia
# Buenos Aires    4.297829
# Buenos Aires    4.314015
# Buenos Aires    4.328098
# Buenos Aires    4.340684
# Buenos Aires    4.351567
#                   ...
# Tucumán         4.318954
# Tucumán         4.332705
# Tucumán         4.344714
# Tucumán         4.355169
# Tucumán         4.364117
# Name: varones, Length: 144, dtype: float64

# %% [markdown]
# #Convertir una columna al tipo datetime
#
# A menudo una columna contiene cadenas que representan fechas. Para convertir estas cadenas al tipo datatime se utiliza el siguiente metodo
#
#         *to_datatime(columna, formato):
#           Devuelve la serie que resulta de convertir las cadenas de la columna en fechas del tipo datatime con el formato especificado
#
#
# https://aprendeconalf.es/docencia/python/manual/pandas/#convertir-una-columna-al-tipo-datetime

# %%
import pandas as pd
df = pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")

print(pd.to_datetime(df["anio"], format="%Y"))
# Out:
# provincia
# Buenos Aires   2015-01-01
# Buenos Aires   2020-01-01
# Buenos Aires   2025-01-01
# Buenos Aires   2030-01-01
# Buenos Aires   2035-01-01
#                   ...
# Tucumán        2020-01-01
# Tucumán        2025-01-01
# Tucumán        2030-01-01
# Tucumán        2035-01-01
# Tucumán        2040-01-01
# Name: anio, Length: 144, dtype: datetime64[ns]

# %% [markdown]
# #Resumen descriptivo de un DataFrame
#
# Al igual que para las series, los siguientes métodos permiten resumir la indormación de un DataFrame por columnas
#
#       * df.count():
#         Devuelve una serie con el núero de elementos que no son nulos ni NaN en cada columna del DataFrame df
#       * df.sum():
#         Devuelve una serie con la suma de los datos de las columnas del DataFrame df cuando los datos son de tipo númerico, o la concatenación de ellos cuando son del tipo string
#       * df.cumsum():
#         Devuelve un DataFrame con las uma acumulada de los datos de las columnas del DataFrame df cuando los datos de un tipo numérico
#       * df.min():
#         Devuelve una serie con los menores de los datos de las columnas del DataFrame
#       * df.max():
#         Devuelve una serie con los mayores de los datos de las columnas del DataFrame
#       * df.mean():
#         Devuelve una serie con lsa medidas de los datos de las columnas númericas
#       * df.var(): Que tan dispersos están los datos, cuanto se alejan del valor promedio
#         Devuelve una serie con las varianzas de los datos de la columnas
#       * df.std():
#         Devuelve una serie con las desviaciones típicas de los datos de las columnas numéricas del DataFrame
#       * df.corr():
#         Devuelve un DataFrame con los coeficientes de coleción de pearson  de los datos de las columnas numericas
#       * df.cov():
#         Devuelve un DataFrame con las covarianza de los datos de las columnas numéricas del DataFrame.
#       * df.describe(include=tipo):
#         Devuelve un DataFrame con un resumen estadpistico de las columnas del DataFrame df del tipo tip. Para los datos numéricos(number) se calcula la media, la desviación típica, el minimo, el maximo y los cuartiles. Para los datos no numéricos(objetc]) se calcula el número de valores, el número de valores distintios, la moda y su frecuencia. Si no se indica el tipo solo se consideran las columnas númericas

# %%
#Cantidad de filas en año
df.anio.count()
#Media de mujeres
df.mujeres.mean()
#Deviación tipica en varones
print(df.varones.std())
#Matriz de covarianza
df.cov()
#Correlacion
df.corr()

df.describe()
# Out:
# 1.749619117170093
#               anio     mujeres     varones
# count   144.000000  144.000000  144.000000
# mean   2027.500000   82.710347   76.417778
# std       8.568931    1.637181    1.749619
# min    2015.000000   78.320000   71.530000
# 25%    2020.000000   81.525000   75.177500
# 50%    2027.500000   82.865000   76.595000
# 75%    2035.000000   84.117500   77.890000
# max    2040.000000   85.460000   79.270000

# %%
import pandas as pd
ruta = ("/content/drive/MyDrive/Bases de datos /exportaciones.csv")
df =pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")
df.head()
# Out:
#              provincia  anio      value
# rubro
# Total       Total País  2005  40386.762
# Total     Buenos Aires  2005  15626.865
# Total  Capital Federal  2005    271.295
# Total          Córdoba  2005   4452.178
# Total       Entre Ríos  2005    815.341

# %% [markdown]
# #Eliminar columnas de un DataFrame
#
# Para eliminar columnas de un DataFrame se utilizan los siguientes métodos
#
#
#       del d[nombre]
#         Elimina la columna con el nombre nombre del DataFrame df
#
#       df.pop(nombre):
#         Elimina la columna con nombre del DataFrame df y la devuelve como una serie

# %%
import pandas as pd
ff = pd.read_csv('https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv')
del ff['sexo']
ff.pop("edad")
# Out:
# 0     18
# 1     32
# 2     24
# 3     35
# 4     46
# 5     68
# 6     51
# 7     22
# 8     35
# 9     46
# 10    53
# 11    58
# 12    27
# 13    20
# Name: edad, dtype: int64

# %% [markdown]
# #Operaciones con las filas de un DataFrame

# %% [markdown]
# #Añadir una fila a un DataFrame
# Para añadir una fila a un DataFrame
#
#     * Creamos la serie y la guardamos en una nueva variable
#     * Concatenamos la variable con el DataFrame
#     * To_fame = convierte la serie en un DataFrame
#     * .T convierte la fila a columnas
#     * Ignore_Index = Unifica la indexación para que no hayan datos repetidos

# %%
nuevo = (pd.Series(['Carlos Rivas', 28, 'H', 89.0, 1.78, 245.0], index=['nombre','edad','sexo','peso','altura','colesterol']))
ff = pd.concat([ff,nuevo.to_frame().T], ignore_index=True)
ff.tail()
#Imprimí varias veces jaja
# Out:
#                              nombre   peso altura colesterol edad sexo
# 10            Macarena Álvarez Luna   55.0   1.62      262.0  NaN  NaN
# 11       José María de la Guía Sanz   78.0   1.87      198.0  NaN  NaN
# 12  Miguel Angel Cuadrado Gutiérrez  109.0   1.98      210.0  NaN  NaN
# 13            Carolina Rubio Moreno   61.0   1.77      194.0  NaN  NaN
# 14                     Carlos Rivas   89.0   1.78      245.0   28    H

# %% [markdown]
# #Eliminar Filas de un DataFrame
# Para eliminar las filas de un DataFrame se utiliza el siguiente metodo
#
#       * df.drop(Filas), axis=0:
#         Devuevle un DataFrame que resulta de eliminar las filas con los nombres indicados en la lista filas del DataFrame

# %%
ff.drop(("sexo"), axis=1) #Elimina Columna
ff.drop(0) #Por defecto tiene axis=0, elimina la fila
# Out:
#                              nombre   peso altura colesterol edad sexo
# 1                    Rosa Díaz Díaz   65.0   1.73      232.0  NaN  NaN
# 2             Javier García Sánchez    NaN   1.81      191.0  NaN  NaN
# 3               Carmen López Pinzón   65.0    1.7      200.0  NaN  NaN
# 4              Marisa López Collado   51.0   1.58      148.0  NaN  NaN
# 5                 Antonio Ruiz Cruz   66.0   1.74      249.0  NaN  NaN
# 6           Antonio Fernández Ocaña   62.0   1.72      276.0  NaN  NaN
# 7             Pilar Martín González   60.0   1.66        NaN  NaN  NaN
# 8              Pedro Gálvez Tenorio   90.0   1.94      241.0  NaN  NaN
# 9           Santiago Reillo Manzano   75.0   1.85      280.0  NaN  NaN
# 10            Macarena Álvarez Luna   55.0   1.62      262.0  NaN  NaN
# 11       José María de la Guía Sanz   78.0   1.87      198.0  NaN  NaN
# 12  Miguel Angel Cuadrado Gutiérrez  109.0   1.98      210.0  NaN  NaN
# ...

# %% [markdown]
# #Filtrar filas de un DataFrame en Padas
#
#       df[condición]:
#       Condición: Es un comparación cómo:
#         df["edad"]>30
#         df["sexo] == "H"
#         df["colesterol"] < 200
#
#       Lo guardamos en una variable, para tener legibilidad o comodidad, sinó devolveria solo True o False

# %%
df
# Out:
#                               provincia  anio      value
# rubro
# Total                        Total País  2005  40386.762
# Total                      Buenos Aires  2005  15626.865
# Total                   Capital Federal  2005    271.295
# Total                           Córdoba  2005   4452.178
# Total                        Entre Ríos  2005    815.341
# ...                                 ...   ...        ...
# Combustibles y energía         San Luis  2020          0
# Combustibles y energía            Chaco  2020          0
# Combustibles y energía       Corrientes  2020    373.938
# Combustibles y energía          Formosa  2020      5.169
# Combustibles y energía         Misiones  2020          0
#
# [2000 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv(ruta, header=0, index_col=0, na_values="NaN", encoding="latin1")
print(df[(df["provincia"] == "Buenos Aires") & (df["anio"] > 2015)])
# Out:
#                                         provincia  anio      value
# rubro
# Total                                Buenos Aires  2016  18534.181
# Productos primarios                  Buenos Aires  2016   4270.238
# Manufacturas de origen agropecuario  Buenos Aires  2016   5299.144
# Manufacturas de origen industrial    Buenos Aires  2016   8411.969
# Combustibles y energía               Buenos Aires  2016    552.831
# Total                                Buenos Aires  2017  19240.844
# Productos primarios                  Buenos Aires  2017   3857.019
# Manufacturas de origen agropecuario  Buenos Aires  2017   5375.539
# Manufacturas de origen industrial    Buenos Aires  2017    9145.28
# Combustibles y energía               Buenos Aires  2017    863.005
# Total                                Buenos Aires  2018  21290.126
# Productos primarios                  Buenos Aires  2018   4021.452
# Manufacturas de origen agropecuario  Buenos Aires  2018   5685.951
# ...

# %% [markdown]
# #Ordenar un DataFrame
#
# Para ordenar un DataFrame de acuerdo a los valores de una determina columna se utilizan los siguientes métodos:
#
#
#
#         * df.sort_value(by="nombre_de_la_columna", ascending=true)
#           Ordenar una sola columna, de mayor a menor, si quieres al reves debes sabar el ascending
#
#
#         * ordenar  por más de una columna
#           df_ordenado = df.sort_values(by={"provincia", "anio"], ascending=[true. false])
#
#
#         * Ordenar por el indice
#           df_ordenado = df.sort_index()
#         si quieres inverso agregas (ascending=false)
#
#
#
#         * Para mantener cambios agregamos
#           , implace=true

# %%
import pandas as pd
df_ordenado =  df.sort_values(by=["provincia", "anio"], ascending=[True, True])
df_ordenado
# Out:
#                                         provincia  anio      value
# rubro
# Total                                Buenos Aires  2005  15626.865
# Productos primarios                  Buenos Aires  2005   2116.442
# Manufacturas de origen agropecuario  Buenos Aires  2005   3244.813
# Manufacturas de origen industrial    Buenos Aires  2005   7787.398
# Combustibles y energía               Buenos Aires  2005   2478.212
# ...                                           ...   ...        ...
# Total                                     Tucumán  2020     773.75
# Productos primarios                       Tucumán  2020    274.227
# Manufacturas de origen agropecuario       Tucumán  2020    226.731
# Manufacturas de origen industrial         Tucumán  2020    271.295
# Combustibles y energía                    Tucumán  2020      1.498
#
# [2000 rows x 3 columns]

# %%
df_ordenar_indice = df.sort_index(ascending=False)
df_ordenar_indice
# Out:
#                          provincia  anio      value
# rubro
# Total                   Total País  2005  40386.762
# Total                   Corrientes  2012    239.855
# Total                   Entre Ríos  2012   1994.901
# Total                     La Pampa  2012    445.639
# Total                     Santa Fe  2012  17931.537
# ...                            ...   ...        ...
# Combustibles y energía       Salta  2017     32.209
# Combustibles y energía    La Rioja  2017          0
# Combustibles y energía       Jujuy  2017          0
# Combustibles y energía   Catamarca  2017          0
# Combustibles y energía    Misiones  2020          0
#
# [2000 rows x 3 columns]

# %% [markdown]
# #Eliminar filas con datos desconocidos en un DataFrame
#
# Que es un dato desconocido?
#
#         NaN = Not a number
#         None = Valor nulo
#         celdas vacias
#
# Como eliminar
#
#         Usando el metodo .dropna()
#
# Eliminar todas las filas con algún dato fatante
#
#         df_sin_nulos = df.dronpa()
#
# Eliminar solo columnas vacias
#
#         df.dropna(how="all")
#
#
# Solo eliminar si faltan datos en columnas específicas:
#
#         df.dopna(subset=["anio" , "value"])
#
#
# Eliminar y guardar cambios directamente
#
#         df.dropna(inplace=True)

# %%
df_sin_nulos = df.dropna()
df_sin_nulos
# Out:
#                               provincia  anio      value
# rubro
# Total                        Total País  2005  40386.762
# Total                      Buenos Aires  2005  15626.865
# Total                   Capital Federal  2005    271.295
# Total                           Córdoba  2005   4452.178
# Total                        Entre Ríos  2005    815.341
# ...                                 ...   ...        ...
# Combustibles y energía         San Luis  2020          0
# Combustibles y energía            Chaco  2020          0
# Combustibles y energía       Corrientes  2020    373.938
# Combustibles y energía          Formosa  2020      5.169
# Combustibles y energía         Misiones  2020          0
#
# [2000 rows x 3 columns]

# %% [markdown]
# #Agrupación de un DataFrame
# en muchas aplicaciones es útil agrupar los datas de un DataFrame de acuerdo a los valores de una o varias columnas (categorías)
#
#
#         Groupby se usa para agrupar datos según una o más columnas y luego aplicar funciones estadisticas o de resumen como suma, promedio, conteo, etc.
#
#
#         ej: quiero saber cuántas ventas se hicieron por provincia. Agrupo por "provincia ", y sumo la columna "ventas"
#
# ![pandas-grupos.png](data:image/png;base64,...)

# %% [markdown]
# #Agrupar datos en pandas
#
#         df.groupby(columnas).groups :
#         Devuelve un diccionario con cuyas claves son las tuplas que resultan de todas las combinaciones de los valores de las columnas con nombres en la lista columnas, y valores las listas de los nombres de las filas que contienen esos valores en las correspondientes columnas del DataFrame df.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv'
df = pd.read_csv(url, na_values="NaN")
df.dropna(inplace=True)
print(df.groupby("sexo").groups)
# Out:
# {'H': [0, 5, 6, 8, 9, 11, 12], 'M': [1, 3, 4, 10, 13]}

# %%
#Calcular promedio
promedio = df.groupby("sexo").mean(numeric_only=True)

#Contar
contar = df.groupby("sexo").size()

#Colesterol Maximo
colesterol_max = df.groupby("edad")["colesterol"].max()


print(promedio)
print(contar)
print(colesterol_max)
# Out:
#            edad       peso    altura  colesterol
# sexo
# H     43.285714  80.714286  1.841429  233.714286
# M     37.200000  59.400000  1.680000  207.200000
# sexo
# H    7
# M    5
# dtype: int64
# edad
# 18    182.0
# 20    194.0
# 27    210.0
# 32    232.0
# 35    241.0
# 46    280.0
# 51    276.0
# 53    262.0
# 58    198.0
# 68    249.0
# Name: colesterol, dtype: float64

# %%
#grupo mixto
grupo_mixto = df.groupby(["sexo","edad"])["colesterol"].mean()
grupo_mixto
# Out:
# sexo  edad
# H     18      182.0
#       27      210.0
#       35      241.0
#       46      280.0
#       51      276.0
#       58      198.0
#       68      249.0
# M     20      194.0
#       32      232.0
#       35      200.0
#       46      148.0
#       53      262.0
# Name: colesterol, dtype: float64

# %% [markdown]
# #Aplicar función de agregación por grupos
# Una vez dividido el DataFrame en grupos, es posible aplicar funciones de agregación a cada grupo mediante el siguiente método
#
#
# Una funcion de agregación toma un conjunto de datos  y devuelve un solo valore resumen
#
#
#         * mean()
#
#         * sum()
#
#         * max()
#
#         * min()
#
#         * count()
#
#         * median()
#
#         * std()
#
#
#
# Funcion agg() permite aplicar una o varias funciones a uno o varios grupos de un data frame
# ✅ Más flexible que .mean() o .sum()
# ✅ Permite aplicar diferentes funciones a diferentes columnas
# ✅ Se ve más ordenado que escribir todo por separado

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/asalber/manual-python/master/datos/colesterol.csv'
df = pd.read_csv(url, na_values="NaN")
df.dropna(inplace=True)

# %%
#Promedio colesterol por sexo:

df.groupby("sexo")["colesterol"].mean()
# Out:
# sexo
# H    233.714286
# M    207.200000
# Name: colesterol, dtype: float64

# %%
#Suma total de peso por sexo

df.groupby("sexo")["peso"].sum()
# Out:
# sexo
# H    565.0
# M    297.0
# Name: peso, dtype: float64

# %%
#Resetear el index, para que no pase al primer parametro como indice
promedios = df.groupby("sexo")["colesterol"].mean().reset_index()
promedios
# Out:
#   sexo  colesterol
# 0    H  233.714286
# 1    M  207.200000

# %%
#Varias funciones a la vez
df.groupby("sexo")["colesterol"].agg(["mean","max","min"]).reset_index()
# Out:
#   sexo        mean    max    min
# 0    H  233.714286  280.0  182.0
# 1    M  207.200000  262.0  148.0

# %%
#Agregar multiples columnas con multiples funciones

df.groupby("sexo").agg({
    "edad": ["mean", "max"],
    "colesterol": ["mean", "min", "max"]}).reset_index()
# Out:
#   sexo       edad      colesterol
#              mean max        mean    min    max
# 0    H  43.285714  68  233.714286  182.0  280.0
# 1    M  37.200000  53  207.200000  148.0  262.0

# %% [markdown]
# #Reestructurar un DataFrame
#
# A menudo la disposición de los datos en un DataFrame no es la adecuada para su tratamiento y es necesario reestructurar el DataFrame. Los Datos que contiene un DataFrame pueden organizarse en dos formatos: ancho y largo
# ![formatos-dataframe.png](data:image/png;base64,...)

# %% [markdown]
# #Convertir un DataFrame a formato largo
#
# Tambien conocido con "Formato tidy" o "long format". Es súper útil para análisis, visualizaciones y machie learnig
#
# * Cada variable en su propia columna
# * Cada observación en su propia fila
#
#
#       Se usa la funcion pd.melt()
#
# Parametros
#
#       * id_vars:
#         columnas que no se van a derretir, se mantienen fijas como el nombre
#
#       * value_vars: las columnas que querés convertir en filas
#
#       * var_name: cómo se va a llamar la nueva columna con los nombres originales
#
#       * value_name: nombre para los valores de esas columnas

# %%
"""
df_largo = pd.melt(df, id_vars=["sexo"],
                   value_vars=["colesterol_2020", "colesterol_2021"],
                   var_name="año",
                   value_name="colesterol")
"""
# Out:
# '\ndf_largo = pd.melt(df, id_vars=["sexo"], \n                   value_vars=["colesterol_2020", "colesterol_2021"],\n                   var_name="año", \n                   value_name="colesterol")\n'

# %% [markdown]
# #Formato ancho
#
# el formato ancho (wide format) es cuando da variables tiene su propia columna y cada observacion ocupa una sola fila

# %%
#Agrupar por sexo,

df_ancho = df.pivot_table(index="nombre", columns="sexo", values="colesterol")
df_ancho
# Out:
# sexo                                 H      M
# nombre
# Antonio Fernández Ocaña          276.0    NaN
# Antonio Ruiz Cruz                249.0    NaN
# Carmen López Pinzón                NaN  200.0
# Carolina Rubio Moreno              NaN  194.0
# José Luis Martínez Izquierdo     182.0    NaN
# José María de la Guía Sanz       198.0    NaN
# Macarena Álvarez Luna              NaN  262.0
# Marisa López Collado               NaN  148.0
# Miguel Angel Cuadrado Gutiérrez  210.0    NaN
# Pedro Gálvez Tenorio             241.0    NaN
# Rosa Díaz Díaz                     NaN  232.0
# Santiago Reillo Manzano          280.0    NaN

# %% [markdown]
# #Conbinar varios DataFrames
#
# dos o más DataFrames puede conbinarse en otro DataFrame. La combinacion puede ser de varias formas:
#
#        * Concatenación: Combinación de varios DataFrames concatenando sus filas o columnas
#
#       * Mezcla: Cominación de varios DataFrames usando columnas o índices comunes

# %% [markdown]
# #Concatenación de DataFrames
#
#
#       Concatenación de filas. Las filas de dos DataFrames se concatenan unas a continuación de las otras para formar el nuevo DataFrame. Para ello es necesario que los Data Frames se conbinen y tengan el mismo índice de columnas
#           Verticalmente
#
#
#       concatenación de columnas. Las columnas de los Data Frames se concatenan unas a continuación de las otras para formar el nuevo DataFrame. Para ello es necesario que los DataFrame que se combinen tengan el mismo índice de filas
#           Horizontalmente
#
#
#
#
# si los DataFrame que se concatenan por filas no tienen el mismo índice de columnas, el DataFrame resultante incuirá todas las columnas exitentes en los DataFrames y rellenará con valores NaN los datos no disponibles. Si los DataFrames que se concatenan por columnas no tienen el mismo índice de filas, el DataFrame resultante incluirpa todas las filas existentes en los DataFarme y rellenará con valores NaN de los datos no disponibles

# %%
import pandas as pd
#Concatenar filas
df1 = pd.DataFrame({"Nombre": ["Carmen", "Luis"],
                    "Sexo": ["Mujer","Hombre"], "Edad": [22,18]}).set_index("Nombre")
df2 = pd.DataFrame({"Nombre":["María", "Pedro"], "Sexo":["Mujer", "Hombre"], "Edad":[25, 30]}).set_index("Nombre")

df = pd.concat([df1,df2])
df
# Out:
#           Sexo  Edad
# Nombre
# Carmen   Mujer    22
# Luis    Hombre    18
# María    Mujer    25
# Pedro   Hombre    30

# %%
import pandas as pd
#Concatenar columnas
df1 = pd.DataFrame({"Nombre":["Carmen", "Luis", "María"],
                    "Sexo":["Mujer", "Hombre", "Mujer"]}).set_index("Nombre")
df2 = pd.DataFrame({"Nombre":["Carmen", "Luis", "María"],
                    "Edad":[22, 18, 25]}).set_index("Nombre")
dff = pd.concat([df1,df2], axis=1)
dff
# Out:
#           Sexo  Edad
# Nombre
# Carmen   Mujer    22
# Luis    Hombre    18
# María    Mujer    25

# %% [markdown]
# #Mezclar DataFrames
# ![1_9eH1_7VbTZPZd9jBiGIyNA.png](data:image/png;base64,...)

# %% [markdown]
# La mezcla de DataFrames permite integrar filas de dos DataFrames que contienen información en común en una o varias columnas o índices que se conocen como clave
#
# Para mezclar dos DataFrames se utiliza el siguiente método
#         df.merge(df1,df2,on=clave, how=tipo)
#           Devuelve el DataFrame que resulta de mezclar el DataFrame df2 con el DataFrame df1, usando como claves las columnas de la lista clave y sieguiendo el método indicado por tipo
#
#
#           inner(por defecto): El DataFrame resultante solo contiene las filas cuyo valores en la clave están en los dos DataFrames. Es equivalente a la intersección de conjuntos

# %% [markdown]
#   #inner
#
#         inner(por defecto): El DataFrame resultante solo contiene las filas cuyo valores en la clave están en los dos DataFrames. Es equivalente a la intersección de conjuntos
#
#
#
# ```
# #On=["id_provincia, "anio]: le decimos con que columnas queremos unir
#
# how="inner": conserva solo las filas que están en ambas tablas con la misma combinación de id_provincia y anio
# ```

# %%
import pandas as pd
ruta = "/content/drive/MyDrive/Bases de datos /bases_api_normalizada.xlsx"

vida =  pd.read_excel(ruta, sheet_name="esperanza_de_vida")
poblacion1 =pd.read_excel(ruta, sheet_name="poblacion")

poblacion = poblacion1[(poblacion1["id_provincia"].notna()) & (poblacion1["id_provincia"] != 25)]

print(vida.head())
print(poblacion.head())
# Out:
#    id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0             1  2015                   80.22                   73.54
# 1             1  2020                   81.34                   74.74
# 2             1  2025                   82.32                   75.80
# 3             1  2030                   83.20                   76.76
# 4             1  2035                   83.98                   77.60
#
#   nivel_territorial
# 0         Provincia
# 1         Provincia
# 2         Provincia
# 3         Provincia
# 4         Provincia
#     id_provincia  anio  poblacion_total  poblacion_varones  poblacion_mujeres  \
# 31           2.0  2010          3028481            1405566            1622915
# 32           2.0  2011          3033639            1409835            1623804
# 33           2.0  2012          3038860            1414105            1624755
# 34           2.0  2013          3044076            1418339            1625737
# ...

# %%
df_merged = pd.merge(vida,poblacion, on=["id_provincia", "anio"], how="inner")

df_merged
# Out:
#      id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0               1  2015                   80.22                   73.54
# 1               1  2020                   81.34                   74.74
# 2               1  2025                   82.32                   75.80
# 3               1  2030                   83.20                   76.76
# 4               1  2035                   83.98                   77.60
# ..            ...   ...                     ...                     ...
# 139            24  2020                   81.05                   75.11
# 140            24  2025                   82.11                   76.15
# 141            24  2030                   83.03                   77.07
# 142            24  2035                   83.84                   77.88
# 143            24  2040                   84.54                   78.58
#
#     nivel_territorial_x  poblacion_total  poblacion_varones  \
# ...

# %% [markdown]
# #Left join
#
# El DataFrame resultante contiene todas las filas del primer DataFrame y descarta las filas del segundo DataFrame que no puedan emparejarse con alguna fila del primer DataFrame a través de la clave
#
# * Se conservan todas las filas del DataFrame de la izquierda
# * Y se agregan las columnas de la derecha solo si hay coincidencia
# * Si no hay coincidencia, completa con un NaN
#
#
# Es util cuando: Quieres mantener todos tus datos principales y agregar info complementaria si está

# %%
df_left = pd.merge(vida,poblacion, on=["id_provincia", "anio"], how="left")


print(df_left.shape) #Cuantas filas y columnas
print(df_left.head()) #Primeras fila
print(df_left.isna().sum()) #Ver si hay valores faltantes
# Out:
# (144, 9)
#    id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0             1  2015                   80.22                   73.54
# 1             1  2020                   81.34                   74.74
# 2             1  2025                   82.32                   75.80
# 3             1  2030                   83.20                   76.76
# 4             1  2035                   83.98                   77.60
#
#   nivel_territorial_x  poblacion_total  poblacion_varones  poblacion_mujeres  \
# 0           Provincia         16659931            8158456            8501475
# 1           Provincia         17541141            8607537            8933604
# 2           Provincia         18359753            9024621            9335132
# 3           Provincia         19123592            9413737            9709855
# 4           Provincia         19839191            9778732           10060459
#
#   nivel_territorial_y
# 0           Provincia
# 1           Provincia
# ...

# %% [markdown]
# #Rigth join
#
# es exactamente lo contrario a left join:
# El DataFrame resultante contiene todas las filas del segundo DataFrame y descarta las filas del primero DataFrame que no puedan emparejarse con alguna fila del segundo DataFrame a través de la clave
#
# * Se conservan todas las filas del DataFrame de la derecha
# * Y se agregan las columnas de la izquierda solo si hay coincidencia
# * Si no hay coincidencia, completa con un NaN
#
#
# Es util cuando: Quieres mantener todos tus datos principales y agregar info complementaria si está

# %%
df_right = pd.merge(vida, poblacion, on=["id_provincia", "anio"], how="right")

print(df_right.shape)
print(df_right.head())
print(df_right.isna().sum())
# Out:
# (744, 9)
#    id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0           2.0  2010                     NaN                     NaN
# 1           2.0  2011                     NaN                     NaN
# 2           2.0  2012                     NaN                     NaN
# 3           2.0  2013                     NaN                     NaN
# 4           2.0  2014                     NaN                     NaN
#
#   nivel_territorial_x  poblacion_total  poblacion_varones  poblacion_mujeres  \
# 0                 NaN          3028481            1405566            1622915
# 1                 NaN          3033639            1409835            1623804
# 2                 NaN          3038860            1414105            1624755
# 3                 NaN          3044076            1418339            1625737
# 4                 NaN          3049229            1422507            1626722
#
#   nivel_territorial_y
# 0           Provincia
# 1           Provincia
# ...

# %% [markdown]
# #Outer join
#
# El DataFramee resultante contiene todas las filas de los dos DataFrames. Si una fila de un DataFrane no puede emparejarse con otra los mismo valores en la clave con el otro DataFrame, la fila se añade igualmente al DataFrame resultante rellenando las columnas del otro DataFrame con el valor NaN. Es quivalente a la unión de conjuntos.
#
# * Todas las filas de ambos DataFrames
# * Si hay coincidencia se unen
# * si no hay coincidencias, completa los datos faltantes con NaN

# %%
df_outer = pd.merge(vida,poblacion, on=["id_provincia" ,"anio"], how="outer")

print(df_outer.shape)
print(df_outer.head())
print(df_outer.isna().sum())
# Out:
# (744, 9)
#    id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0           1.0  2010                     NaN                     NaN
# 1           1.0  2011                     NaN                     NaN
# 2           1.0  2012                     NaN                     NaN
# 3           1.0  2013                     NaN                     NaN
# 4           1.0  2014                     NaN                     NaN
#
#   nivel_territorial_x  poblacion_total  poblacion_varones  poblacion_mujeres  \
# 0                 NaN         15716942            7678592            8038350
# 1                 NaN         15909607            7776525            8133082
# 2                 NaN         16100618            7873684            8226934
# 3                 NaN         16289599            7969864            8319735
# 4                 NaN         16476149            8064849            8411300
#
#   nivel_territorial_y
# 0           Provincia
# 1           Provincia
# ...

# %%
import pandas as pd
df_vida = pd.read_excel(ruta, sheet_name="esperanza_de_vida")
problacion1 = pd.read_excel(ruta, sheet_name="poblacion")
df_empleo = pd.read_excel(ruta,sheet_name="empleo")
poblacion = poblacion1[(poblacion1["id_provincia"].notna()) & (poblacion1["id_provincia"] != 25)]

columnas_vida = df_vida.columns
columnas_poblacion = poblacion.columns
columnas_empleo = df_empleo.columns
print(columnas_vida)
print(columnas_poblacion)
print(columnas_empleo)
# Out:
# Index(['id_provincia', 'anio', 'esperanza_vida_mujeres',
#        'esperanza_vida_varones', 'nivel_territorial'],
#       dtype='object')
# Index(['id_provincia', 'anio', 'poblacion_total', 'poblacion_varones',
#        'poblacion_mujeres', 'nivel_territorial'],
#       dtype='object')
# Index(['id_provincia', 'anio', 'mes', 'empleados_registrados_miles',
#        'nivel_territorial'],
#       dtype='object')

# %%
df_vida_poblacion = pd.merge(df_vida,poblacion, on=["id_provincia", "anio"], how="inner")

df_final= pd.merge(df_vida_poblacion,df_empleo, on=["id_provincia", "anio"], how="inner")

df_final
# Out:
#      id_provincia  anio  esperanza_vida_mujeres  esperanza_vida_varones  \
# 0               1  2015                   80.22                   73.54
# 1               1  2015                   80.22                   73.54
# 2               1  2015                   80.22                   73.54
# 3               1  2015                   80.22                   73.54
# 4               1  2015                   80.22                   73.54
# ..            ...   ...                     ...                     ...
# 571            24  2020                   81.05                   75.11
# 572            24  2020                   81.05                   75.11
# 573            24  2020                   81.05                   75.11
# 574            24  2020                   81.05                   75.11
# 575            24  2020                   81.05                   75.11
#
#     nivel_territorial_x  poblacion_total  poblacion_varones  \
# ...
